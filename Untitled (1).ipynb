# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Pasan Lahiru__
#
# Data Engineer

# %% [markdown]
# _Data Science is also the electricity that powers the industries of today. Industries need data to improve their performance, make their business grow and provide better products to their customers. In the scenario of data science section, we took an example of a commercial industry that wants to maximize its sales._

# %% [markdown]
# ### The following code is created instance method for fibonacci sequence by recursive

# %%
class Fibonacci_squence:
    def Fibonacci(self,number):
        if (number==0) or (number==1):
            return(1)
        else:
            sumnation=number+self.Fibonacci(number-1)
        return(sumnation)
result=Fibonacci_squence()
result.Fibonacci(10)
# Out:
# 55

# %% [markdown]
# <ol>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ol>
#
# <ul>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ul>
#
# | Item         | Price     | # In stock |
# |--------------|-----------|------------|
# | Juicy Apples | 1.99      | *7*        |
# | Bananas      | **1.89**  | 5234       |
